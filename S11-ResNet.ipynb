# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank-Gottumukkala/ERA-S11/blob/main/S11-ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Shashank-Gottumukkala/core.git
# %pushd core
# !git pull
# !pip install -qr library.txt
# %ls
# %popd
# Out:
# Cloning into 'core'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 129 (delta 61), reused 94 (delta 32), pack-reused 0
# Receiving objects: 100% (129/129), 37.36 KiB | 1.38 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /content/core
# Already up to date.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 48.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Dataset/  __init__.py  library.txt  main.py  models/  README.md  utils/
# /content
# popd -> /content

# %%
from core.main import *
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_lr_finder/lr_finder.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Device Selected: cuda
# ...
# 100%|██████████| 170498071/170498071 [00:01<00:00, 106234060.70it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified

# %%
cifar10.show_examples()

# %%
print_summary(model)
# Out:
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Param %
# ...
# ResNet                                   [64, 3, 32, 32]           [64, 10]                  --                             --
# ├─Conv2d: 1-1                            [64, 3, 32, 32]           [64, 64, 32, 32]          1,728                       0.02%
# ├─BatchNorm2d: 1-2                       [64, 64, 32, 32]          [64, 64, 32, 32]          128                         0.00%
# ├─Sequential: 1-3                        [64, 64, 32, 32]          [64, 64, 32, 32]          --                             --
# │    └─ConvBlock: 2-1                    [64, 64, 32, 32]          [64, 64, 32, 32]          --                             --
# │    │    └─Conv2d: 3-1                  [64, 64, 32, 32]          [64, 64, 32, 32]          36,864                      0.33%
# ...

# %%
experiment = create_experiment(model, cifar10, criterion='crossentropy', epochs=20, scheduler='one_cycle')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 3.85E-03

# %%
experiment.execute()
# Out:
# Epoch: 1
# Train: Loss: 1.8021, Train_Accuracy: 33.57 LR: 0.000800753186518084: 100%|██████████| 782/782 [00:45<00:00, 17.34it/s]
# Test: Loss: 1.5952, Test_Accuracy: 41.03
# Epoch: 2
# Train: Loss: 1.3903, Train_Accuracy: 49.17 LR: 0.001563947038316196: 100%|██████████| 782/782 [00:46<00:00, 16.82it/s]
# Test: Loss: 1.9230, Test_Accuracy: 43.94
# Epoch: 3
# Train: Loss: 1.1935, Train_Accuracy: 57.15 LR: 0.002327140890114308: 100%|██████████| 782/782 [00:46<00:00, 16.64it/s]
# Test: Loss: 0.9951, Test_Accuracy: 64.77
# Epoch: 4
# Train: Loss: 1.0565, Train_Accuracy: 62.32 LR: 0.0030903347419124197: 100%|██████████| 782/782 [00:46<00:00, 16.69it/s]
# Test: Loss: 0.8108, Test_Accuracy: 71.77
# Epoch: 5
# Train: Loss: 0.9590, Train_Accuracy: 66.03 LR: 0.0038535285937105314: 100%|██████████| 782/782 [00:46<00:00, 16.68it/s]
# Test: Loss: 0.8566, Test_Accuracy: 70.89
# Epoch: 6
# ...

# %%
experiment.train.plot_stats()

# %%
experiment.test.plot_stats()

# %%
experiment.show_incorrect()
# Out:
# Test: Loss: 0.2909, Test_Accuracy: 90.25

# %%
experiment.show_incorrect(cams=True)
